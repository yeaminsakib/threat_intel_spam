# %% [markdown]
# # Exploratory Data Analysis
#
# Use this notebook to inspect collected emails, headers, and IoCs.

# %%
from pathlib import Path

project_root = Path('..').resolve()
data_dir = project_root / 'data'
data_dir
